# %%
db.Categorias.insertMany([
    { 
        _id: ObjectId(), 
        nombre: "Computadoras", 
        descripcion: "Dispositivos de cómputo como laptops y PCs" 
    },
    { 
        _id: ObjectId(), 
        nombre: "Accesorios", 
        descripcion: "Accesorios de tecnología como mouses, teclados y otros periféricos" 
    },
    { 
        _id: ObjectId(), 
        nombre: "Almacenamiento", 
        descripcion: "Dispositivos de almacenamiento como discos duros y memorias USB" 
    },
    { 
        _id: ObjectId(), 
        nombre: "Fotografía", 
        descripcion: "Equipos de fotografía y video, incluyendo cámaras y accesorios" 
    },
    { 
        _id: ObjectId(), 
        nombre: "Audio", 
        descripcion: "Productos de audio como audífonos, parlantes y sistemas de sonido" 
    },
    { 
        _id: ObjectId(), 
        nombre: "Impresión", 
        descripcion: "Impresoras y accesorios de impresión como cartuchos y papel fotográfico" 
    },
    { 
        _id: ObjectId(), 
        nombre: "Redes", 
        descripcion: "Equipos de redes como routers, switches y adaptadores de red" 
    },
    { 
        _id: ObjectId(), 
        nombre: "Monitores", 
        descripcion: "Monitores y pantallas para uso doméstico o profesional" 
    },
    { 
        _id: ObjectId(), 
        nombre: "Software", 
        descripcion: "Programas y software para diferentes aplicaciones, como edición de video o antivirus" 
    },
    { 
        _id: ObjectId(), 
        nombre: "Gaming", 
        descripcion: "Accesorios y equipos para gaming, incluyendo consolas y accesorios de videojuegos" 
    }
]);

# %%
if (db.Categorias.countDocuments() === 0) {
    db.Categorias.insertMany([
        { nombre: "Computadoras", descripcion: "Dispositivos de cómputo como laptops y PCs" },
        { nombre: "Accesorios", descripcion: "Accesorios de tecnología como mouses y teclados" },
        { nombre: "Almacenamiento", descripcion: "Dispositivos de almacenamiento como memorias RAM" },
        { nombre: "Fotografía", descripcion: "Equipos de fotografía como cámaras" }
    ]);
}

# %%
[
    {
        "_id": ObjectId("64f1f9d7b6c6f34c88e4f6e1"),
        "nombre": "Computador Dell XPS 13",
        "descripcion": "Computador portátil de alto rendimiento con procesador Intel Core i7, 16GB RAM y 512GB SSD.",
        "precio": 1200.50,
        "stock": 50,
        "categoria_id": ObjectId("64f1f9d7b6c6f34c88e4f6e0"),
        "imagenes": [
            "imagen_1_1.jpg",
            "imagen_1_2.jpg"
        ],
        "atributos": {
            "color": "plata",
            "tamaño": "13 pulgadas"
        },
        "fecha_creacion": ISODate("2024-11-07T10:30:00Z"),
        "fecha_actualizacion": ISODate("2024-11-07T10:30:00Z")
    },
    {
        "_id": ObjectId("64f1f9d7b6c6f34c88e4f6e2"),
        "nombre": "Mouse Logitech G502 Hero",
        "descripcion": "Mouse gaming con sensor HERO de 16,000 DPI, botones programables y diseño ergonómico.",
        "precio": 79.99,
        "stock": 120,
        "categoria_id": ObjectId("64f1f9d7b6c6f34c88e4f6e1"),
        "imagenes": [
            "imagen_2_1.jpg",
            "imagen_2_2.jpg"
        ],
        "atributos": {
            "color": "negro",
            "tamaño": "tamaño mediano"
        },
        "fecha_creacion": ISODate("2024-11-07T10:31:00Z"),
        "fecha_actualizacion": ISODate("2024-11-07T10:31:00Z")
    },
    {
        "_id": ObjectId("64f1f9d7b6c6f34c88e4f6e3"),
        "nombre": "Teclado mecánico Razer BlackWidow V3",
        "descripcion": "Teclado mecánico con retroiluminación RGB, teclas mecánicas y conmutadores Razer Green.",
        "precio": 129.99,
        "stock": 80,
        "categoria_id": ObjectId("64f1f9d7b6c6f34c88e4f6e2"),
        "imagenes": [
            "imagen_3_1.jpg",
            "imagen_3_2.jpg"
        ],
        "atributos": {
            "color": "negro",
            "tamaño": "estándar"
        },
        "fecha_creacion": ISODate("2024-11-07T10:32:00Z"),
        "fecha_actualizacion": ISODate("2024-11-07T10:32:00Z")
    },
    {
        "_id": ObjectId("64f1f9d7b6c6f34c88e4f6e4"),
        "nombre": "Memoria RAM Corsair Vengeance LPX 16GB",
        "descripcion": "Memoria RAM DDR4 de 16GB, 3200MHz, ideal para videojuegos y tareas exigentes.",
        "precio": 69.99,
        "stock": 150,
        "categoria_id": ObjectId("64f1f9d7b6c6f34c88e4f6e0"),
        "imagenes": [
            "imagen_4_1.jpg",
            "imagen_4_2.jpg"
        ],
        "atributos": {
            "color": "negro",
            "tamaño": "16GB"
        },
        "fecha_creacion": ISODate("2024-11-07T10:33:00Z"),
        "fecha_actualizacion": ISODate("2024-11-07T10:33:00Z")
    },
    {
        "_id": ObjectId("64f1f9d7b6c6f34c88e4f6e5"),
        "nombre": "Cámara Canon EOS 90D",
        "descripcion": "Cámara réflex digital de 32.5MP, video 4K, con enfoque automático Dual Pixel.",
        "precio": 1399.00,
        "stock": 60,
        "categoria_id": ObjectId("64f1f9d7b6c6f34c88e4f6e2"),
        "imagenes": [
            "imagen_5_1.jpg",
            "imagen_5_2.jpg"
        ],
        "atributos": {
            "color": "negro",
            "tamaño": "estándar"
        },
        "fecha_creacion": ISODate("2024-11-07T10:34:00Z"),
        "fecha_actualizacion": ISODate("2024-11-07T10:34:00Z")
    }
]

# %%
[
    {
        "_id": ObjectId("64f1f9d7b6c6f34c88e4f6e1"),
        "nombre": "Producto 1",
        "descripcion": "Descripción del producto 1",
        "precio": 573.65,
        "stock": 156,
        "categoria_id": ObjectId("64f1f9d7b6c6f34c88e4f6e0"),
        "imagenes": [
            "imagen_1_1.jpg",
            "imagen_1_2.jpg"
        ],
        "atributos": {
            "color": "rojo",
            "tamaño": "M"
        },
        "fecha_creacion": ISODate("2024-11-07T10:30:00Z"),
        "fecha_actualizacion": ISODate("2024-11-07T10:30:00Z")
    },
    {
        "_id": ObjectId("64f1f9d7b6c6f34c88e4f6e2"),
        "nombre": "Producto 2",
        "descripcion": "Descripción del producto 2",
        "precio": 289.95,
        "stock": 34,
        "categoria_id": ObjectId("64f1f9d7b6c6f34c88e4f6e1"),
        "imagenes": [
            "imagen_2_1.jpg",
            "imagen_2_2.jpg"
        ],
        "atributos": {
            "color": "azul",
            "tamaño": "L"
        },
        "fecha_creacion": ISODate("2024-11-07T10:31:00Z"),
        "fecha_actualizacion": ISODate("2024-11-07T10:31:00Z")
    },
    {
        "_id": ObjectId("64f1f9d7b6c6f34c88e4f6e3"),
        "nombre": "Producto 3",
        "descripcion": "Descripción del producto 3",
        "precio": 14.75,
        "stock": 78,
        "categoria_id": ObjectId("64f1f9d7b6c6f34c88e4f6e2"),
        "imagenes": [
            "imagen_3_1.jpg",
            "imagen_3_2.jpg"
        ],
        "atributos": {
            "color": "verde",
            "tamaño": "S"
        },
        "fecha_creacion": ISODate("2024-11-07T10:32:00Z"),
        "fecha_actualizacion": ISODate("2024-11-07T10:32:00Z")
    },
    {
        "_id": ObjectId("64f1f9d7b6c6f34c88e4f6e4"),
        "nombre": "Producto 4",
        "descripcion": "Descripción del producto 4",
        "precio": 752.20,
        "stock": 120,
        "categoria_id": ObjectId("64f1f9d7b6c6f34c88e4f6e0"),
        "imagenes": [
            "imagen_4_1.jpg",
            "imagen_4_2.jpg"
        ],
        "atributos": {
            "color": "negro",
            "tamaño": "XL"
        },
        "fecha_creacion": ISODate("2024-11-07T10:33:00Z"),
        "fecha_actualizacion": ISODate("2024-11-07T10:33:00Z")
    },
    {
        "_id": ObjectId("64f1f9d7b6c6f34c88e4f6e5"),
        "nombre": "Producto 5",
        "descripcion": "Descripción del producto 5",
        "precio": 420.50,
        "stock": 90,
        "categoria_id": ObjectId("64f1f9d7b6c6f34c88e4f6e1"),
        "imagenes": [
            "imagen_5_1.jpg",
            "imagen_5_2.jpg"
        ],
        "atributos": {
            "color": "rojo",
            "tamaño": "M"
        },
        "fecha_creacion": ISODate("2024-11-07T10:34:00Z"),
        "fecha_actualizacion": ISODate("2024-11-07T10:34:00Z")
    }
]

# %%
db.Blockbuster.updateOne(
    { codigo: 1 },
    { $addToSet: { productoras: "Nueva Productora" } }
);

# %%
db.Blockbuster.deleteOne({ codigo: 1 });

# %%
db.Blockbuster.countDocuments({ director: "Carlos Pérez" });

# %%
db.Blockbuster.find({ titulo: { $regex: "Viaje", $options: "i" } });

# %%
db.Blockbuster.find(
    { director: { $regex: "^A", $options: "i" } },
    { titulo: 1, productoras: 1, _id: 0 }
)

# %%
db.Blockbuster.find(
    { $expr: { $gt: [{ $strLenCP: "$titulo" }, 15] } },
    { titulo: 1, codigo: 1, _id: 0 }
);

# %%
db.Blockbuster.find(
    { "productoras.1": { $exists: true } },
    { titulo: 1, director: 1, _id: 0 }
);
